# %% [markdown]
# # Top 5 Zipcodes to Invest In
#
# ## 1. Overview
# *fill in later*
#
# ##  2. Buisness Problem
#
# A real estate investment firm centered in Philadelphia reached out to a consultant to help them figure out **"What are the top 5 best zip codes for us to invest in?"**.  The goal of the analysis in this notebook is to answer the stakeholder's question by reccomending the top 5 zipcodes to invest in the Philly Metro area *and* explain the logic behind those reccomendations.
#
#
# ----
#
#
# ## 3. Dataset
# The dataset was origionally extracted from [Zillow Research](https://www.zillow.com/research/data/) and was taken from this [repo](https://github.com/learn-co-curriculum/dsc-phase-4-choosing-a-dataset/tree/main/time-series).
#
# Zillow is an website that advertises properties for rent or sale all over the USA. Due to it's easy accessability and expansive data collection throughout the USA, we chose to use this dataset to evaluate our data. In the raw data, we had **14,723** rows and **272** columns, but after changing the shape of our data so as to hace a seperate row for each unique zipcode and date we had **3,744,704** rows and **7** columns. The dataset covers from April 1996 through April 2018, and includes the median sales information for every month between those years.

# %% [markdown]
# ## Initial Look at the Data
#
# ### Imports

# %%
#imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import statsmodels.api as sm
from matplotlib.pylab import rcParams
from statsmodels.tsa.stattools import adfuller
import itertools
import statsmodels.api as sm

#import numpy.typing
from prophet import Prophet

# %%
# initial look at the raw data and importing the second column (with the zipcodes) as an object, not an integer
data = pd.read_csv("zillow_data.csv", dtype={'RegionName': object})
data.head()
# Out:
#    RegionID RegionName      City State              Metro CountyName  \
# 0     84654      60657   Chicago    IL            Chicago       Cook
# 1     90668      75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982      77494      Katy    TX            Houston     Harris
# 3     84616      60614   Chicago    IL            Chicago       Cook
# 4     93144      79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(48), object(5)
# memory usage: 30.6+ MB

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# We are going to get rid of the columns `RegionID` and `SizeRank` as they seem irrelevant to our current line of questioning. (We don't care about the size or region of the zipcodes we reccomend.) We are then going to reformat our data so we can look for and deal with any NaN's we may come across.

# %%
data.drop(['RegionID', 'SizeRank'], axis=1, inplace=True)

# %%
data.head()
# Out:
#   RegionName      City State              Metro CountyName   1996-04  \
# 0      60657   Chicago    IL            Chicago       Cook  334200.0
# 1      75070  McKinney    TX  Dallas-Fort Worth     Collin  235700.0
# 2      77494      Katy    TX            Houston     Harris  210400.0
# 3      60614   Chicago    IL            Chicago       Cook  498100.0
# 4      79936   El Paso    TX            El Paso    El Paso   77300.0
#
#     1996-05   1996-06   1996-07   1996-08  ...  2017-07  2017-08  2017-09  \
# 0  335400.0  336500.0  337600.0  338500.0  ...  1005500  1007500  1007800
# 1  236900.0  236700.0  235400.0  233300.0  ...   308000   310000   312500
# 2  212200.0  212200.0  210700.0  208300.0  ...   321000   320600   320200
# 3  500900.0  503100.0  504600.0  505500.0  ...  1289800  1287700  1287400
# 4   77300.0   77300.0   77300.0   77400.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 270 columns]

# %%
# pulling out Philly data specifically 
phil_data = data.loc[data["Metro"]== "Philadelphia"]
phil_data
# Out:
#       RegionName              City State         Metro    CountyName  \
# 194        19111      Philadelphia    PA  Philadelphia  Philadelphia
# 282        19124      Philadelphia    PA  Philadelphia  Philadelphia
# 329        19446          Lansdale    PA  Philadelphia    Montgomery
# 343        19020          Bensalem    PA  Philadelphia         Bucks
# 351        19720        New Castle    DE  Philadelphia    New Castle
# ...          ...               ...   ...           ...           ...
# 13729      08026         Gibbsboro    NJ  Philadelphia        Camden
# 14189      08067           Oldmans    NJ  Philadelphia         Salem
# 14239      19453  Upper Providence    PA  Philadelphia    Montgomery
# 14496      18915          Hatfield    PA  Philadelphia    Montgomery
# 14537      08328          Franklin    NJ  Philadelphia    Gloucester
#
#         1996-04   1996-05   1996-06   1996-07   1996-08  ...  2017-07  \
# 194     84600.0   84500.0   84400.0   84200.0   84100.0  ...   167100
# 282     43100.0   43000.0   42900.0   42700.0   42500.0  ...    79800
# 329    155300.0  154900.0  154600.0  154200.0  153900.0  ...   305400
# 343    122000.0  121800.0  121600.0  121300.0  121000.0  ...   250000
# 351     91300.0   92000.0   92600.0   93200.0   93600.0  ...   173100
# ...         ...       ...       ...       ...       ...  ...      ...
# 13729  100500.0  100800.0  101100.0  101300.0  101500.0  ...   174200
# 14189   81300.0   81600.0   81900.0   82100.0   82400.0  ...   145400
# 14239  110100.0  109900.0  109700.0  109500.0  109300.0  ...   210900
# 14496  165300.0  165300.0  165400.0  165400.0  165400.0  ...   316500
# 14537   86700.0   86800.0   87000.0   87100.0   87200.0  ...   151700
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 194     168100   169300   170600   171900   172700   173200   174000   175200
# 282      80900    82200    83000    83800    84300    84200    84900    86700
# 329     307700   309200   309300   308800   308900   310100   311600   314000
# 343     251600   252600   253800   255400   256400   257500   257600   255600
# 351     173200   172600   173400   178700   185200   189000   189400   184700
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 13729   172800   173400   174300   174500   171100   166000   165200   171300
# 14189   146400   147000   147200   147800   148400   147900   150500   158500
# 14239   212100   212500   213700   215300   217500   220200   222400   223800
# 14496   318300   320200   321600   322000   322000   322700   323900   325700
# 14537   150500   150000   151900   155600   158500   159900   161100   161700
#
#        2018-04
# 194     175800
# 282      88200
# 329     315900
# 343     253400
# 351     179000
# ...        ...
# 13729   176600
# 14189   165900
# 14239   224800
# 14496   327000
# 14537   161300
#
# [281 rows x 270 columns]

# %%
#checking for null values
phil_data[pd.isna(phil_data).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [RegionName, City, State, Metro, CountyName, 1996-04, 1996-05, 1996-06, 1996-07, 1996-08, 1996-09, 1996-10, 1996-11, 1996-12, 1997-01, 1997-02, 1997-03, 1997-04, 1997-05, 1997-06, 1997-07, 1997-08, 1997-09, 1997-10, 1997-11, 1997-12, 1998-01, 1998-02, 1998-03, 1998-04, 1998-05, 1998-06, 1998-07, 1998-08, 1998-09, 1998-10, 1998-11, 1998-12, 1999-01, 1999-02, 1999-03, 1999-04, 1999-05, 1999-06, 1999-07, 1999-08, 1999-09, 1999-10, 1999-11, 1999-12, 2000-01, 2000-02, 2000-03, 2000-04, 2000-05, 2000-06, 2000-07, 2000-08, 2000-09, 2000-10, 2000-11, 2000-12, 2001-01, 2001-02, 2001-03, 2001-04, 2001-05, 2001-06, 2001-07, 2001-08, 2001-09, 2001-10, 2001-11, 2001-12, 2002-01, 2002-02, 2002-03, 2002-04, 2002-05, 2002-06, 2002-07, 2002-08, 2002-09, 2002-10, 2002-11, 2002-12, 2003-01, 2003-02, 2003-03, 2003-04, 2003-05, 2003-06, 2003-07, 2003-08, 2003-09, 2003-10, 2003-11, 2003-12, 2004-01, 2004-02, ...]
# Index: []
#
# [0 rows x 270 columns]

# %%
# create metrics to judge return on investment (ROI)

# total ROI
phil_data['t_growth'] = (phil_data['2018-04'] - phil_data['1996-04']) / phil_data['1996-04']
# ROI pre-2008 crash 
phil_data['growth1'] = (phil_data['2007-09'] - phil_data['1996-04']) / phil_data['1996-04']
#ROI after 2008 crash 
phil_data['growth2'] = (phil_data['2018-04'] - phil_data['2011-03']) / phil_data['2011-03']
# re-check the info in a bit more manageable slice
phil_shortform = phil_data.loc[:,['RegionName','City','State','Metro','CountyName','t_growth','growth1','growth2']]
phil_shortform.head()
# Out:
# <ipython-input-8-d9de391fa1f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phil_data['t_growth'] = (phil_data['2018-04'] - phil_data['1996-04']) / phil_data['1996-04']
# <ipython-input-8-d9de391fa1f0>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phil_data['growth1'] = (phil_data['2007-09'] - phil_data['1996-04']) / phil_data['1996-04']
# <ipython-input-8-d9de391fa1f0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phil_data['growth2'] = (phil_data['2018-04'] - phil_data['2011-03']) / phil_data['2011-03']
#     RegionName          City State         Metro    CountyName  t_growth  \
# 194      19111  Philadelphia    PA  Philadelphia  Philadelphia  1.078014
# 282      19124  Philadelphia    PA  Philadelphia  Philadelphia  1.046404
# 329      19446      Lansdale    PA  Philadelphia    Montgomery  1.034127
# 343      19020      Bensalem    PA  Philadelphia         Bucks  1.077049
# 351      19720    New Castle    DE  Philadelphia    New Castle  0.960570
#
#       growth1   growth2
# 194  1.141844  0.132003
# 282  1.125290  0.119289
# 329  1.020605  0.144151
# 343  1.204918  0.109457
# 351  1.111720  0.198928

# %%
# checking for null values 
phil_data[pd.isna(phil_data).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [RegionName, City, State, Metro, CountyName, 1996-04, 1996-05, 1996-06, 1996-07, 1996-08, 1996-09, 1996-10, 1996-11, 1996-12, 1997-01, 1997-02, 1997-03, 1997-04, 1997-05, 1997-06, 1997-07, 1997-08, 1997-09, 1997-10, 1997-11, 1997-12, 1998-01, 1998-02, 1998-03, 1998-04, 1998-05, 1998-06, 1998-07, 1998-08, 1998-09, 1998-10, 1998-11, 1998-12, 1999-01, 1999-02, 1999-03, 1999-04, 1999-05, 1999-06, 1999-07, 1999-08, 1999-09, 1999-10, 1999-11, 1999-12, 2000-01, 2000-02, 2000-03, 2000-04, 2000-05, 2000-06, 2000-07, 2000-08, 2000-09, 2000-10, 2000-11, 2000-12, 2001-01, 2001-02, 2001-03, 2001-04, 2001-05, 2001-06, 2001-07, 2001-08, 2001-09, 2001-10, 2001-11, 2001-12, 2002-01, 2002-02, 2002-03, 2002-04, 2002-05, 2002-06, 2002-07, 2002-08, 2002-09, 2002-10, 2002-11, 2002-12, 2003-01, 2003-02, 2003-03, 2003-04, 2003-05, 2003-06, 2003-07, 2003-08, 2003-09, 2003-10, 2003-11, 2003-12, 2004-01, 2004-02, ...]
# Index: []
#
# [0 rows x 273 columns]

# %%
# re-check the info in a bit more manageable slice
phil_shortform.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 281 entries, 194 to 14537
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionName  281 non-null    object
#  1   City        281 non-null    object
#  2   State       281 non-null    object
#  3   Metro       281 non-null    object
#  4   CountyName  281 non-null    object
#  5   t_growth    281 non-null    float64
#  6   growth1     281 non-null    float64
#  7   growth2     281 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 19.8+ KB

# %%
phil_shortform.describe()
# Out:
#          t_growth     growth1     growth2
# count  281.000000  281.000000  281.000000
# mean     1.086182    1.181123    0.114567
# std      0.755744    0.430239    0.132367
# min      0.237132    0.713235   -0.147526
# 25%      0.774878    1.004141    0.040498
# 50%      0.960227    1.108796    0.114919
# 75%      1.148588    1.209726    0.165386
# max      7.046012    4.311475    1.059172

# %%
# find the top 5 zipcodes in Philadelphia who grew the most after the 2008 crash
phil_shortform.sort_values('growth2',ascending=False).head(5)
# Out:
#      RegionName          City State         Metro    CountyName  t_growth  \
# 666       19145  Philadelphia    PA  Philadelphia  Philadelphia  4.155556
# 3615      19125  Philadelphia    PA  Philadelphia  Philadelphia  7.046012
# 518       19148  Philadelphia    PA  Philadelphia  Philadelphia  4.111922
# 940       19103  Philadelphia    PA  Philadelphia  Philadelphia  3.784584
# 784       19147  Philadelphia    PA  Philadelphia  Philadelphia  5.941176
#
#        growth1   growth2
# 666   1.975309  1.059172
# 3615  3.288344  0.956003
# 518   2.481752  0.586858
# 940   2.756508  0.542373
# 784   4.105169  0.541568

# %%
# find the top 5 zipcodes who had the worst recovery after the crash
phil_shortform.sort_values('growth2',ascending=False).tail(5)
# Out:
#       RegionName             City State         Metro  CountyName  t_growth  \
# 678        08021       Lindenwold    NJ  Philadelphia      Camden  0.471698
# 12781      08063    National Park    NJ  Philadelphia  Gloucester  0.476942
# 9024       19079      Sharon Hill    PA  Philadelphia    Delaware  0.425076
# 8037       08079            Salem    NJ  Philadelphia       Salem  0.436765
# 7613       08030  Gloucester City    NJ  Philadelphia      Camden  0.402458
#
#         growth1   growth2
# 678    1.100236 -0.102804
# 12781  1.134709 -0.107117
# 9024   0.738532 -0.136237
# 8037   1.039706 -0.139965
# 7613   1.227343 -0.147526

# %% [markdown]
# ## Initial Visualizations

# %%
plt.gcf().autofmt_xdate()
phil_shortform[['RegionName','growth2']].sort_values(by='growth2',ascending=False).plot.bar(x='RegionName', y='growth2',figsize=(20,20))
plt.title('ROI Growth (post 2008 Crash) for All Zip Codes in Philadelphia, PA', fontsize=30)
plt.legend('')
plt.xlabel('Zip codes',fontsize=20)
plt.ylabel('Growth Percentage',fontsize=20)
#plt.gcf().autofmt_xdate()
# Out:
# Text(0, 0.5, 'Growth Percentage')

# %%
# formatting for the rest of our visualizations
font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)

# %%
ax = phil_shortform[['RegionName','growth2']].sort_values(by='growth2',ascending=False).head(15).plot.bar(x='RegionName', y='growth2',figsize=(16,8))
plt.title('ROI Growth After 2008 Crash: Top 15 Zip Codes in Philadelphia', fontsize=25)
plt.legend('')
ax.set_yticklabels([0, "20%", "40%", "60%", "80%", "100%"])
plt.xlabel('Zip Codes',fontsize=20)
plt.ylabel('Growth Percentage',fontsize=20)
# Out:
# <ipython-input-16-b6fa667de586>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0, "20%", "40%", "60%", "80%", "100%"])
# Text(0, 0.5, 'Growth Percentage')

# %% [markdown]
# ## Melting the Data

# %%
phil_data.head()
# Out:
#     RegionName          City State         Metro    CountyName   1996-04  \
# 194      19111  Philadelphia    PA  Philadelphia  Philadelphia   84600.0
# 282      19124  Philadelphia    PA  Philadelphia  Philadelphia   43100.0
# 329      19446      Lansdale    PA  Philadelphia    Montgomery  155300.0
# 343      19020      Bensalem    PA  Philadelphia         Bucks  122000.0
# 351      19720    New Castle    DE  Philadelphia    New Castle   91300.0
#
#       1996-05   1996-06   1996-07   1996-08  ...  2017-10  2017-11  2017-12  \
# 194   84500.0   84400.0   84200.0   84100.0  ...   170600   171900   172700
# 282   43000.0   42900.0   42700.0   42500.0  ...    83000    83800    84300
# 329  154900.0  154600.0  154200.0  153900.0  ...   309300   308800   308900
# 343  121800.0  121600.0  121300.0  121000.0  ...   253800   255400   256400
# 351   92000.0   92600.0   93200.0   93600.0  ...   173400   178700   185200
#
#      2018-01  2018-02  2018-03  2018-04  t_growth   growth1   growth2
# 194   173200   174000   175200   175800  1.078014  1.141844  0.132003
# 282    84200    84900    86700    88200  1.046404  1.125290  0.119289
# 329   310100   311600   314000   315900  1.034127  1.020605  0.144151
# 343   257500   257600   255600   253400  1.077049  1.204918  0.109457
# 351   189000   189400   184700   179000  0.960570  1.111720  0.198928
#
# [5 rows x 273 columns]

# %%
#pulling out the date columns so we can more easily change the format later on
dates = phil_data.loc[:, ~phil_data.columns.isin(['RegionName','City', 'State', 'Metro', 'CountyName', 't_growth', 'growth1', 'growth2'])]

# %%
# adjusting the column names so we can use pd.melt later
column_names_to_change = {}

for column in dates.columns:
    column_names_to_change[column] = f'{column}-01'
    
phil_data.rename(columns=column_names_to_change, inplace=True)

phil_data.head()
# Out:
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     RegionName          City State         Metro    CountyName  1996-04-01  \
# 194      19111  Philadelphia    PA  Philadelphia  Philadelphia     84600.0
# 282      19124  Philadelphia    PA  Philadelphia  Philadelphia     43100.0
# 329      19446      Lansdale    PA  Philadelphia    Montgomery    155300.0
# 343      19020      Bensalem    PA  Philadelphia         Bucks    122000.0
# 351      19720    New Castle    DE  Philadelphia    New Castle     91300.0
#
#      1996-05-01  1996-06-01  1996-07-01  1996-08-01  ...  2017-10-01  \
# 194     84500.0     84400.0     84200.0     84100.0  ...      170600
# 282     43000.0     42900.0     42700.0     42500.0  ...       83000
# 329    154900.0    154600.0    154200.0    153900.0  ...      309300
# 343    121800.0    121600.0    121300.0    121000.0  ...      253800
# 351     92000.0     92600.0     93200.0     93600.0  ...      173400
#
#      2017-11-01  2017-12-01  2018-01-01  2018-02-01  2018-03-01  2018-04-01  \
# 194      171900      172700      173200      174000      175200      175800
# 282       83800       84300       84200       84900       86700       88200
# 329      308800      308900      310100      311600      314000      315900
# 343      255400      256400      257500      257600      255600      253400
# 351      178700      185200      189000      189400      184700      179000
#
#      t_growth   growth1   growth2
# 194  1.078014  1.141844  0.132003
# 282  1.046404  1.125290  0.119289
# 329  1.034127  1.020605  0.144151
# 343  1.077049  1.204918  0.109457
# 351  0.960570  1.111720  0.198928
#
# [5 rows x 273 columns]

# %%
phil_data.iloc[:185]
# Out:
#      RegionName          City State         Metro    CountyName  1996-04-01  \
# 194       19111  Philadelphia    PA  Philadelphia  Philadelphia     84600.0
# 282       19124  Philadelphia    PA  Philadelphia  Philadelphia     43100.0
# 329       19446      Lansdale    PA  Philadelphia    Montgomery    155300.0
# 343       19020      Bensalem    PA  Philadelphia         Bucks    122000.0
# 351       19720    New Castle    DE  Philadelphia    New Castle     91300.0
# ...         ...           ...   ...           ...           ...         ...
# 8369      19317   Chadds Ford    PA  Philadelphia      Delaware    230000.0
# 8371      08093     Westville    NJ  Philadelphia    Gloucester     82900.0
# 8414      19344   Honey Brook    PA  Philadelphia       Chester    133700.0
# 8431      21911    Rising Sun    MD  Philadelphia         Cecil    111600.0
# 8551      19350    New Garden    PA  Philadelphia       Chester    219000.0
#
#       1996-05-01  1996-06-01  1996-07-01  1996-08-01  ...  2017-10-01  \
# 194      84500.0     84400.0     84200.0     84100.0  ...      170600
# 282      43000.0     42900.0     42700.0     42500.0  ...       83000
# 329     154900.0    154600.0    154200.0    153900.0  ...      309300
# 343     121800.0    121600.0    121300.0    121000.0  ...      253800
# 351      92000.0     92600.0     93200.0     93600.0  ...      173400
# ...          ...         ...         ...         ...  ...         ...
# 8369    230100.0    230200.0    230300.0    230500.0  ...      465200
# 8371     82800.0     82700.0     82700.0     82700.0  ...      129200
# 8414    134000.0    134100.0    134300.0    134400.0  ...      244400
# 8431    111400.0    111200.0    111000.0    110700.0  ...      223300
# 8551    218600.0    218100.0    217600.0    217200.0  ...      372400
#
#       2017-11-01  2017-12-01  2018-01-01  2018-02-01  2018-03-01  2018-04-01  \
# 194       171900      172700      173200      174000      175200      175800
# 282        83800       84300       84200       84900       86700       88200
# 329       308800      308900      310100      311600      314000      315900
# 343       255400      256400      257500      257600      255600      253400
# 351       178700      185200      189000      189400      184700      179000
# ...          ...         ...         ...         ...         ...         ...
# 8369      467400      468800      470100      473300      478100      481100
# 8371      130500      133000      134900      135300      134100      132900
# 8414      245600      247200      248800      250600      253000      254700
# 8431      223300      223700      224700      226100      228000      229700
# 8551      374400      375600      377200      378100      378400      378400
#
#       t_growth   growth1   growth2
# 194   1.078014  1.141844  0.132003
# 282   1.046404  1.125290  0.119289
# 329   1.034127  1.020605  0.144151
# 343   1.077049  1.204918  0.109457
# 351   0.960570  1.111720  0.198928
# ...        ...       ...       ...
# 8369  1.091739  1.035652  0.221066
# 8371  0.603136  1.095296 -0.068676
# 8414  0.905011  0.933433  0.133511
# 8431  1.058244  1.386201  0.044091
# 8551  0.727854  0.800913  0.091119
#
# [185 rows x 273 columns]

# %%
# pulling out the top 5 zipcodes 
# Philly45 = phil_data.loc[(phil_data['RegionName'] == '19145')]
# Philly25 = phil_data.loc[(phil_data['RegionName'] == '19125')]
# Philly48 = phil_data.loc[(phil_data['RegionName'] == '19148')]
# Philly03 = phil_data.loc[(phil_data['RegionName'] == '19103')]
# Philly47 = phil_data.loc[(phil_data['RegionName'] == '19147')]


top_10_philly = phil_data.sort_values(by='growth2',ascending=False).head(10)
top_10_philly
# Out:
#      RegionName          City State         Metro    CountyName  1996-04-01  \
# 666       19145  Philadelphia    PA  Philadelphia  Philadelphia     40500.0
# 3615      19125  Philadelphia    PA  Philadelphia  Philadelphia     32600.0
# 518       19148  Philadelphia    PA  Philadelphia  Philadelphia     41100.0
# 940       19103  Philadelphia    PA  Philadelphia  Philadelphia    195900.0
# 784       19147  Philadelphia    PA  Philadelphia  Philadelphia     56100.0
# 5214      19123  Philadelphia    PA  Philadelphia  Philadelphia     61000.0
# 531       19131  Philadelphia    PA  Philadelphia  Philadelphia     36700.0
# 1807      19130  Philadelphia    PA  Philadelphia  Philadelphia     76600.0
# 5510      19106  Philadelphia    PA  Philadelphia  Philadelphia    298900.0
# 4747      19428  Conshohocken    PA  Philadelphia    Montgomery    114800.0
#
#       1996-05-01  1996-06-01  1996-07-01  1996-08-01  ...  2017-10-01  \
# 666      40500.0     40500.0     40500.0     40400.0  ...      195900
# 3615     32700.0     32800.0     32800.0     32900.0  ...      253900
# 518      41100.0     41000.0     40900.0     40700.0  ...      198600
# 940     196800.0    197600.0    198400.0    199100.0  ...      888500
# 784      55600.0     55000.0     54500.0     54000.0  ...      376600
# 5214     60600.0     60300.0     59900.0     59600.0  ...      392500
# 531      36700.0     36800.0     36900.0     37000.0  ...       83200
# 1807     76700.0     76700.0     76600.0     76500.0  ...      419000
# 5510    298900.0    298900.0    298800.0    298700.0  ...     1025300
# 4747    114800.0    114700.0    114700.0    114700.0  ...      314700
#
#       2017-11-01  2017-12-01  2018-01-01  2018-02-01  2018-03-01  2018-04-01  \
# 666       197100      198000      199500      202500      206500      208800
# 3615      255700      257100      258000      258500      260500      262300
# 518       199700      201000      202000      203800      207400      210100
# 940       898900      905000      909200      918200      930400      937300
# 784       377600      377400      378000      381200      386400      389400
# 5214      394900      397700      400600      403500      406700      409300
# 531        86600       90300       93600       95500       97000       98600
# 1807      422500      425600      428500      429700      429400      428700
# 5510     1042700     1058500     1066200     1069800     1081700     1095700
# 4747      313400      312900      313400      314500      316500      318400
#
#       t_growth   growth1   growth2
# 666   4.155556  1.975309  1.059172
# 3615  7.046012  3.288344  0.956003
# 518   4.111922  2.481752  0.586858
# 940   3.784584  2.756508  0.542373
# 784   5.941176  4.105169  0.541568
# 5214  5.709836  4.311475  0.508662
# 531   1.686649  1.130790  0.478261
# 1807  4.596606  3.567885  0.356646
# 5510  2.665775  2.334560  0.321075
# 4747  1.773519  1.267422  0.310288
#
# [10 rows x 273 columns]

# %%
def after_crash(df):
    #reduce data so we only will see the dates/values after the market recoved from the 2008 crash
    df_after_crash = df.drop(df.columns[5:185], axis=1,inplace=True)  
    return df_after_crash


after_crash(top_10_philly)
top_10_philly
# Out:
#      RegionName          City State         Metro    CountyName  2011-04-01  \
# 666       19145  Philadelphia    PA  Philadelphia  Philadelphia    101400.0
# 3615      19125  Philadelphia    PA  Philadelphia  Philadelphia    132300.0
# 518       19148  Philadelphia    PA  Philadelphia  Philadelphia    130100.0
# 940       19103  Philadelphia    PA  Philadelphia  Philadelphia    605700.0
# 784       19147  Philadelphia    PA  Philadelphia  Philadelphia    251100.0
# 5214      19123  Philadelphia    PA  Philadelphia  Philadelphia    268600.0
# 531       19131  Philadelphia    PA  Philadelphia  Philadelphia     66200.0
# 1807      19130  Philadelphia    PA  Philadelphia  Philadelphia    316300.0
# 5510      19106  Philadelphia    PA  Philadelphia  Philadelphia    825800.0
# 4747      19428  Conshohocken    PA  Philadelphia    Montgomery    241700.0
#
#       2011-05-01  2011-06-01  2011-07-01  2011-08-01  ...  2017-10-01  \
# 666     100400.0     98100.0     96600.0     95700.0  ...      195900
# 3615    129400.0    126500.0    124400.0    122900.0  ...      253900
# 518     127500.0    124200.0    121300.0    119300.0  ...      198600
# 940     605100.0    599600.0    595200.0    596300.0  ...      888500
# 784     249600.0    248500.0    248900.0    250900.0  ...      376600
# 5214    262000.0    254900.0    251600.0    251900.0  ...      392500
# 531      65800.0     66100.0     66500.0     66800.0  ...       83200
# 1807    315000.0    311400.0    308200.0    306900.0  ...      419000
# 5510    826600.0    821800.0    815800.0    814200.0  ...     1025300
# 4747    240200.0    239700.0    239300.0    238100.0  ...      314700
#
#       2017-11-01  2017-12-01  2018-01-01  2018-02-01  2018-03-01  2018-04-01  \
# 666       197100      198000      199500      202500      206500      208800
# 3615      255700      257100      258000      258500      260500      262300
# 518       199700      201000      202000      203800      207400      210100
# 940       898900      905000      909200      918200      930400      937300
# 784       377600      377400      378000      381200      386400      389400
# 5214      394900      397700      400600      403500      406700      409300
# 531        86600       90300       93600       95500       97000       98600
# 1807      422500      425600      428500      429700      429400      428700
# 5510     1042700     1058500     1066200     1069800     1081700     1095700
# 4747      313400      312900      313400      314500      316500      318400
#
#       t_growth   growth1   growth2
# 666   4.155556  1.975309  1.059172
# 3615  7.046012  3.288344  0.956003
# 518   4.111922  2.481752  0.586858
# 940   3.784584  2.756508  0.542373
# 784   5.941176  4.105169  0.541568
# 5214  5.709836  4.311475  0.508662
# 531   1.686649  1.130790  0.478261
# 1807  4.596606  3.567885  0.356646
# 5510  2.665775  2.334560  0.321075
# 4747  1.773519  1.267422  0.310288
#
# [10 rows x 93 columns]

# %%
def melt_data(df):
    # melting the data so we have it in the long version, instead of wide
    melted = pd.melt(df, id_vars=['RegionName', 'City', 'State', 'Metro', 'CountyName', 't_growth', 'growth1', 'growth2'], var_name='time')
    # makeing our new column `time` a datetime variable 
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    # getting rid of rows that are missing `value` values
    melted_nonan = melted.dropna(subset=['value'])
    #set `time` as index so we can model it as a time series dataset
    melted_nonan.set_index('time',inplace=True)
    # drop all the columns we no longer need
    melted_nonan.drop(labels = ['RegionName', 'City', 'State', 'Metro', 'CountyName', 't_growth', 'growth1', 'growth2'], axis=1, inplace=True)
    return  melted_nonan

# %%
zip_list = []
for zip_code in top_10_philly['RegionName']:
    zip_list.append(zip_code)
zip_list
# Out:
# ['19145',
#  '19125',
#  '19148',
#  '19103',
#  '19147',
#  '19123',
#  '19131',
#  '19130',
#  '19106',
#  '19428']

# %%
top_10_melt = []
for zip_code in top_10_philly['RegionName']:
     top_10_melt.append({
         'zip_code': zip_code,
         'data': melt_data(top_10_philly.loc[(top_10_philly['RegionName'] == zip_code)])
     })
    
top_10_melt[0]['data']
# Out:
#                value
# time
# 2011-04-01  101400.0
# 2011-05-01  100400.0
# 2011-06-01   98100.0
# 2011-07-01   96600.0
# 2011-08-01   95700.0
# ...              ...
# 2017-12-01  198000.0
# 2018-01-01  199500.0
# 2018-02-01  202500.0
# 2018-03-01  206500.0
# 2018-04-01  208800.0
#
# [85 rows x 1 columns]

# %% [markdown]
# ## Stationizing the Data

# %%
for zip_code_melt in top_10_melt:
    zip_code_melt['data'].plot(title=  f"Philadelphia {zip_code_melt['zip_code']}", figsize = (16,6));

# %%
ax = top_10_melt[0]['data'].plot(figsize = (16,8))

for i in range(1, 10):
    top_10_melt[i]['data'].plot(ax=ax)
ax.set_yticklabels([0, "200,000", "400,000", "600,000", "800,000", "1,000,000"])
ax.set_xlabel("Year")
ax.set_ylabel("Median Real Estate Value ($)")
plt.title('Top 10 Philadelphia Zipcodes')
# code taken from https://stackoverflow.com/questions/4700614/how-to-put-the-legend-outside-the-plot
ax.legend(zip_list, loc='center left', bbox_to_anchor=(1, 0.5))
# # creating unique colors for each zipcode https://stackoverflow.com/questions/53199728/how-can-i-stop-matplotlib-from-repeating-colors
# NUM_COLORS = len(zip_list)
# cm = plt.get_cmap('gist_rainbow')
# fig = plt.figure()
# ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
# for i in range(NUM_COLORS):
#     ax.plot(np.arange(10)*(i+1))
# fig.savefig('moreColors.png');
# Out:
# <ipython-input-27-6263856e331b>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0, "200,000", "400,000", "600,000", "800,000", "1,000,000"])

# %% [markdown]
# Now that we have a basic view of how to zipcodes values changed over time, lets check for stationality for each zipcode. We can see above that all of these zipcodes have an upward *trend*, but lets check using the Dickey Fuller Test and the rolling mean.

# %%
# Create a function to check for the stationarity of a given time series using rolling stats and DF test
# Code taken from https://github.com/learn-co-curriculum/dsc-removing-trends-lab

def stationarity_check(TS, TS_zip):
    
    # Import adfuller
    from statsmodels.tsa.stattools import adfuller
    
    # Calculate rolling statistics
    roll_mean = TS.rolling(window=8, center=False).mean()
    roll_std = TS.rolling(window=8, center=False).std()
    
    # Perform the Dickey Fuller Test
    dftest = adfuller(TS['value'])
    
    # Plot rolling statistics:
    fig = plt.figure(figsize=(12,6))
    plt.plot(TS, color='blue',label='Original')
    plt.plot(roll_mean, color='red', label='Rolling Mean')
    plt.plot(roll_std, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title(f"{TS_zip} Rolling Mean & Standard Deviation")
    plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print('Results of Dickey-Fuller Test: \n')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    return None

# %%
for zip_code in top_10_melt:
    stationarity_check(zip_code['data'], zip_code['zip_code'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                  2.051822
# p-value                         0.998737
# #Lags Used                      7.000000
# Number of Observations Used    77.000000
# Critical Value (1%)            -3.518281
# Critical Value (5%)            -2.899878
# Critical Value (10%)           -2.587223
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                  0.302894
# p-value                         0.977477
# #Lags Used                     10.000000
# Number of Observations Used    74.000000
# Critical Value (1%)            -3.521980
# Critical Value (5%)            -2.901470
# Critical Value (10%)           -2.588072
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                  1.703067
# p-value                         0.998136
# #Lags Used                      5.000000
# Number of Observations Used    79.000000
# Critical Value (1%)            -3.515977
# Critical Value (5%)            -2.898886
# Critical Value (10%)           -2.586694
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                  1.682897
# p-value                         0.998086
# #Lags Used                      8.000000
# Number of Observations Used    76.000000
# Critical Value (1%)            -3.519481
# Critical Value (5%)            -2.900395
# Critical Value (10%)           -2.587498
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                  1.875236
# p-value                         0.998487
# #Lags Used                     11.000000
# Number of Observations Used    73.000000
# Critical Value (1%)            -3.523284
# Critical Value (5%)            -2.902031
# Critical Value (10%)           -2.588371
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                  1.851470
# p-value                         0.998446
# #Lags Used                      4.000000
# Number of Observations Used    80.000000
# Critical Value (1%)            -3.514869
# Critical Value (5%)            -2.898409
# Critical Value (10%)           -2.586439
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                 -1.333717
# p-value                         0.613609
# #Lags Used                      6.000000
# Number of Observations Used    78.000000
# Critical Value (1%)            -3.517114
# Critical Value (5%)            -2.899375
# Critical Value (10%)           -2.586955
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                 -0.692644
# p-value                         0.848646
# #Lags Used                      3.000000
# Number of Observations Used    81.000000
# Critical Value (1%)            -3.513790
# Critical Value (5%)            -2.897943
# Critical Value (10%)           -2.586191
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                  3.384192
# p-value                         1.000000
# #Lags Used                     11.000000
# Number of Observations Used    73.000000
# Critical Value (1%)            -3.523284
# Critical Value (5%)            -2.902031
# Critical Value (10%)           -2.588371
# dtype: float64
# Results of Dickey-Fuller Test:
#
# Test Statistic                  0.298577
# p-value                         0.977279
# #Lags Used                      4.000000
# Number of Observations Used    80.000000
# Critical Value (1%)            -3.514869
# Critical Value (5%)            -2.898409
# Critical Value (10%)           -2.586439
# dtype: float64

# %% [markdown]
# None of our above zipcodes pass the Dicky Fuller test (p-values are much to high) and all of the rolling means show us that they all share an upward linear trend. This means that *none of our data is stationary*. I want to use facebook `prophet` to model and predict the data, but before that we'll have to remove the trend. Our data doesn't have a lot of seasonality (at least just by eyeballing it) but it does have a trend.
#
# I did try taking `np.sqrt` and `np.log`, but it didn't really remove the trends in the way I wanted. Lets try taking the rolling mean and see if that helps at all.

# %%
roll_mean = top_10_melt[0]['data'].rolling(window=8, center=False).mean()
data_minus_roll_mean = top_10_melt[0]['data'] - roll_mean
data_minus_roll_mean
# Out:
#              value
# time
# 2011-04-01     NaN
# 2011-05-01     NaN
# 2011-06-01     NaN
# 2011-07-01     NaN
# 2011-08-01     NaN
# ...            ...
# 2017-12-01  9275.0
# 2018-01-01  7800.0
# 2018-02-01  7787.5
# 2018-03-01  8800.0
# 2018-04-01  8562.5
#
# [85 rows x 1 columns]

# %%
data_minus_roll_mean.dropna(inplace=True)

# %%
fig = plt.figure(figsize=(11,7))
plt.plot(data_minus_roll_mean, color='blue',label='Sales - rolling mean')
plt.legend(loc='best')
plt.title('Sales while the rolling mean is subtracted')
plt.show(block=False)

# %%
stationarity_check(data_minus_roll_mean, top_10_melt[0]['zip_code'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                 -0.885695
# p-value                         0.792647
# #Lags Used                     12.000000
# Number of Observations Used    65.000000
# Critical Value (1%)            -3.535217
# Critical Value (5%)            -2.907154
# Critical Value (10%)           -2.591103
# dtype: float64

# %%
top_10_melt[0]['data']
# Out:
#                value
# time
# 2011-04-01  101400.0
# 2011-05-01  100400.0
# 2011-06-01   98100.0
# 2011-07-01   96600.0
# 2011-08-01   95700.0
# ...              ...
# 2017-12-01  198000.0
# 2018-01-01  199500.0
# 2018-02-01  202500.0
# 2018-03-01  206500.0
# 2018-04-01  208800.0
#
# [85 rows x 1 columns]

# %%
# Use Pandas ewm() to calculate Exponential Weighted Moving Average
exp_roll_mean = top_10_melt[0]['data'].ewm(halflife=2).mean()

# Plot the original data with exp weighted average
fig = plt.figure(figsize=(12,7))
orig = plt.plot(top_10_melt[0]['data'], color='blue',label='Original')
mean = plt.plot(exp_roll_mean, color='red', label='Exponentially Weighted Rolling Mean')
plt.legend(loc='best')
plt.title('Exponentially Weighted Rolling Mean')
plt.show(block=False)

# %%
data_minus_exp_roll_mean = top_10_melt[0]['data'] - exp_roll_mean
data_minus_exp_roll_mean.head(15)
# Out:
#                   value
# time
# 2011-04-01     0.000000
# 2011-05-01  -414.213562
# 2011-06-01 -1484.452689
# 2011-07-01 -1818.951416
# 2011-08-01 -1751.580318
# 2011-09-01  -699.579468
# 2011-10-01   339.639590
# 2011-11-01  1058.626262
# 2011-12-01  1566.502090
# 2012-01-01  1999.839872
# 2012-02-01  1400.864729
# 2012-03-01   351.836277
# 2012-04-01  -385.816587
# 2012-05-01  -483.363897
# 2012-06-01   -58.811543

# %%
fig = plt.figure(figsize=(11,7))
plt.plot(data_minus_exp_roll_mean, color='blue',label='Sales - rolling mean')
plt.legend(loc='best')
plt.title(' Exp Rolling mean is subtracted')
plt.show(block=False)

# %%
data_diff = top_10_melt[0]['data'].diff(periods =2)
data_diff.head(15)
# Out:
#              value
# time
# 2011-04-01     NaN
# 2011-05-01     NaN
# 2011-06-01 -3300.0
# 2011-07-01 -3800.0
# 2011-08-01 -2400.0
# 2011-09-01  -200.0
# 2011-10-01  1900.0
# 2011-11-01  2400.0
# 2011-12-01  2400.0
# 2012-01-01  2500.0
# 2012-02-01  1300.0
# 2012-03-01  -900.0
# 2012-04-01 -1800.0
# 2012-05-01 -1200.0
# 2012-06-01   100.0

# %%
fig = plt.figure(figsize=(11,7))
plt.plot(data_diff, color='blue',label='Sales - rolling mean')
plt.legend(loc='best')
plt.title('Differenced sales series')
plt.show(block=False)

# %%
data_diff.dropna(inplace=True)
stationarity_check(data_diff, top_10_melt[0]['zip_code'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                 -1.159254
# p-value                         0.690874
# #Lags Used                     11.000000
# Number of Observations Used    71.000000
# Critical Value (1%)            -3.526005
# Critical Value (5%)            -2.903200
# Critical Value (10%)           -2.588995
# dtype: float64

# %%
data = np.log(data_diff) 
fig = plt.figure(figsize=(12,6))
plt.plot(data, color='blue')
plt.xlabel('Month', fontsize=14)
plt.title('Sales while the rolling mean is subtracted')
plt.show()
# Out:
# <ipython-input-56-4a2ab6500f9b>:1: RuntimeWarning: invalid value encountered in log
#   data = np.log(data_diff)

# %%
 # may not use this, but it's here for now
def sarima_elements(TS):
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
    
    #warnings.filterwarnings('ignore')
    
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                mod = sm.tsa.statespace.SARIMAX(TS,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

                output = mod.fit()
                ans.append([comb, combs, output.aic])
            except:
                continue
                
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
    out = ans_df.loc[ans_df['aic'].idxmin()]
    #print("The minimum AIC:")
    #print(ans_df.loc[ans_df['aic'].idxmin()])
    return out

# %%
toy_data = sarima_elements(top_10_melt[0]['data'])
# Out:
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
toy_data
# Out:
# pdq         (1, 1, 1)
# pdqs    (0, 1, 1, 12)
# aic           970.408
# Name: 59, dtype: object
